# %% [markdown]
# ## Média Geiométrica, Harmonica e Quadratica

# %% [markdown]
# ![](https://github.com/AdrianoR85/Estatistica-para-Machine-Learning/blob/f5d737ae6c157692628824856c6487db1be3ccf5/assets/medidas02.png?raw=true)

# %% [markdown]
# ## Dados

# %%
import numpy as np

# %%
data = np.array([150, 151, 152, 152, 153, 154, 155, 155, 155, 155, 156, 156, 156,
                  157, 158, 158, 160, 160, 160, 160, 160, 161, 161, 161, 161, 162,
                  163, 163, 164, 164, 164, 165, 166, 167, 168, 168, 169, 170, 172,
                  173])

# %% [markdown]
# ## Média geométrica

# %%
from scipy.stats.mstats import gmean

# %%
gmean(data)
# Out:
# np.float64(160.26958390038905)

# %% [markdown]
# ## Média Harmonica

# %%
from scipy.stats.mstats import hmean

# %%
hmean(data)

# %% [markdown]
# ## Média Quadrática

# %%
rms = np.sqrt(np.mean(data**2))
print(f"Média Quadrática (RMS): {rms:.2f}")
# Out:
# Média Quadrática (RMS): 160.48
